# %%
from pymongo import MongoClient

client = MongoClient("mongodb://extern:12345678@172.16.4.203:27017")
db = client["neo4food"]
collection = db["Restaurants"]

# %%
query = {}

result = collection.find(query, {'category': 1})

# %%
tree = {}

for i in result:
    if 'category' in i:
        l = i['category'].split(", ")
        for x in l:
            if x in tree:
                tree[x]+= 1
            else:
                tree[x] = 1

vect = {}

for key, value in sorted(tree.items(), key=lambda item: item[1], reverse=True):
    vect[key] = value

print(vect)

# %%
for i in vect.keys():
    print(i)

# %%
vect
# Out:
# {'American': 17798,
#  'Burgers': 7001,
#  'Fast Food': 5793,
#  'Sandwich': 4904,
#  'Sandwiches': 4643,
#  'Healthy': 4393,
#  'Asian': 4125,
#  'Comfort Food': 4082,
#  'Family Meals': 4069,
#  'Mexican': 4015,
#  'Breakfast and Brunch': 3782,
#  'Desserts': 3744,
#  'Pizza': 3661,
#  'Salads': 3308,
#  'Chicken': 2704,
#  'Convenience': 2527,
#  'Italian': 2519,
#  'Everyday Essentials': 2485,
#  'Wings': 2101,
#  'Family Friendly': 2061,
#  'Latin American': 2038,
#  'Snacks': 2011,
#  'Vegetarian': 1852,
#  'Seafood': 1779,
#  'New Mexican': 1667,
#  'Chinese': 1640,
#  'Asian Fusion': 1488,
#  'Home &amp; Personal Care': 1380,
#  'Coffee and Tea': 1332,
#  'Japanese': 1320,
#  'Noodles': 1267,
#  'Bakery': 1132,
#  'Pasta': 1094,
#  'Alcohol': 1056,
#  'BBQ': 1041,
#  'Vegetarian Friendly': 1040,
#  'Indian': 1027,
#  'burger': 990,
#  'Juice and Smoothies': 985,
#  'Sushi': 982,
#  'Exclusive to Eats': 939,
#  'Kids Friendly': 900,
#  'Cafe': 863,
#  'Group Friendly': 862,
#  'Mediterranean': 849,
#  'Fried Chicken': 827,
#  'Grocery': 810,
#  'Ice Cream + Frozen Yogurt': 801,
#  'Burritos': 789,
#  'Allergy Friendly': 789,
#  'Thai': 785,
#  'Steak': 775,
#  'wings': 748,
#  'Korean': 687,
#  'Pharmacy': 681,
#  'Southern': 573,
#  'Deli': 566,
#  'Bar Food': 559,
#  'Traditional American': 519,
#  'Greek': 496,
#  'Coffee &amp; Tea': 489,
#  'Vietnamese': 472,
#  'Tacos': 467,
#  'salad': 461,
#  'Vegan': 440,
#  'pizza': 426,
#  'Baby': 411,
#  'Dinner': 381,
#  'Black-owned': 349,
#  'Halal': 319,
#  'Tex Mex': 307,
#  'Middle Eastern': 306,
#  'Soup': 304,
#  'Ice Cream &amp; Frozen Yogurt': 303,
#  'Drinks': 280,
#  'Bubble Tea': 273,
#  'New American': 267,
#  'Donuts': 241,
#  'Breakfast &amp; Brunch': 232,
#  'Vegan Friendly': 225,
#  'Bowls': 216,
#  'Pastry': 197,
#  'Caribbean': 189,
#  'Indian Curry': 188,
#  'Gluten Free': 187,
#  'Gift Store': 186,
#  'Pakistani': 184,
#  'Chicken Strips': 180,
#  'Diner': 176,
#  'Soul Food': 166,
#  'Wine': 163,
#  'Liquor Stores': 154,
#  'Fish and Chips': 150,
#  'Hawaiian': 147,
#  'Rice-bowls': 146,
#  'Gluten Free Friendly': 144,
#  'Ramen': 140,
#  'Rolls': 130,
#  'pasta': 128,
#  'Cajun': 123,
#  'Hot Dog': 117,
#  'PIzza': 117,
#  'Retail': 106,
#  'African': 102,
#  'Omelette': 101,
#  'Cupcakes': 97,
#  'Peruvian': 96,
#  'Ethiopian': 95,
#  'Flowers': 92,
#  'Spanish': 91,
#  'European': 86,
#  'Local Specialities': 82,
#  'Beauty Supply': 77,
#  'French': 67,
#  'Specialty Foods': 63,
#  'Poke': 62,
#  'Modern European': 58,
#  'Arabian': 54,
#  'Rice Dishes': 49,
#  'Fish &amp; Seafood': 47,
#  'Plant Based': 46,
#  'Rice &amp; Curry': 46,
#  'Pub': 46,
#  'Affordable Meals': 46,
#  'Açaí': 46,
#  'Cheesesteak': 44,
#  'Street Food': 42,
#  'Latin Fusion': 41,
#  'florist': 41,
#  'Vegetarian-Friendly': 41,
#  'Lebanese': 41,
#  'South American': 40,
#  'Biryani': 40,
#  'Pretzel': 39,
#  'Falafel': 39,
#  'Pho': 37,
#  'Nepalese': 37,
#  'Plants': 36,
#  'Gifts': 35,
#  'Fried Foods': 35,
#  'Taiwanese': 35,
#  'Gourmet': 35,
#  'South East Asian': 35,
#  'Brazilian': 33,
#  'Mac and Cheese': 31,
#  'Turkish': 30,
#  'Ice Cream': 30,
#  'Kebab': 30,
#  'Jamaican': 29,
#  'Bagels': 28,
#  'Persian': 28,
#  'Salvadorian': 28,
#  'North Indian': 27,
#  'Women-owned': 26,
#  'Asian: Other': 25,
#  'Filipino': 25,
#  'Barfood': 24,
#  'German': 24,
#  'Afghan': 24,
#  'Juice &amp; Smoothies': 23,
#  'chocolatier': 23,
#  'Cheese': 23,
#  'Japanese: Sushi': 23,
#  'Juice': 22,
#  'Juice Bars': 21,
#  'Cantonese': 20,
#  'Asian-owned': 20,
#  'Mongolian': 20,
#  'Empanada': 20,
#  'Venezuelan': 19,
#  'South Indian': 19,
#  'Cuban': 18,
#  'Dount': 18,
#  'AAPI-owned': 18,
#  'Salad / Sandwiches': 18,
#  'To Share': 18,
#  'Himalayan': 18,
#  'Puerto Rican': 18,
#  'Colombian': 17,
#  'Western': 17,
#  'Portuguese': 17,
#  'Chinese: Other': 16,
#  'Kosher': 16,
#  'Keto': 16,
#  'Latin American: Other': 16,
#  'Candy': 15,
#  'Crepe': 15,
#  'Bar / Pub Food': 15,
#  'Beer': 15,
#  'South Asian': 15,
#  'Cakes': 14,
#  'Stir\u200b Fried': 13,
#  'Irish': 13,
#  'Russian': 13,
#  'Gluten-Free Friendly': 13,
#  'Japanese BBQ': 13,
#  'Japanese: Other': 13,
#  'Quesadillas': 13,
#  'Mercado Express': 13,
#  'Dessert: Other': 12,
#  'Northeastern Thai': 12,
#  'Bento': 12,
#  'Argentinian': 12,
#  'Sanwiches': 11,
#  'Laotian': 11,
#  'Beef Noodles': 10,
#  'Creole': 9,
#  'Cajun / Creole': 9,
#  'Tempura': 9,
#  'Japanese set items': 9,
#  'Other': 9,
#  'whatever': 9,
#  'Dumpling House': 9,
#  'BOGO': 9,
#  'Japanese Skewer food': 8,
#  'Northern Thai': 8,
#  'Asado': 8,
#  'Fruit': 7,
#  'Malaysian': 7,
#  'Tamale': 7,
#  'Tapas': 7,
#  'Indonesian': 7,
#  'Spicy Hot Pot': 7,
#  'Australian': 7,
#  'Dumplings': 7,
#  'Pure Veg': 7,
#  'Japanese sweets': 6,
#  'Polish': 6,
#  'African: Other': 6,
#  'Jewish': 6,
#  'Breakfast': 6,
#  'Southern Thai': 6,
#  'Wraps': 6,
#  'Carnicería': 6,
#  'British': 6,
#  'Bangladeshi': 6,
#  'JuiceAndSmoothie': 6,
#  'Egyptian': 5,
#  'Brunch': 5,
#  'Japanese Style curry': 5,
#  'Chinese: Cantonese': 5,
#  'Chinese: Sichuan': 5,
#  'Paleo': 5,
#  'Western-style Japanese Food': 5,
#  'Sandwhiches': 5,
#  'Dosa': 5,
#  'pet supplies': 5,
#  'West African': 5,
#  'Tea &amp; Coffee': 4,
#  'OrganicProducts': 4,
#  'Szechuan': 4,
#  'Hot Pot': 4,
#  'Chinese: Noodles &amp; Dumplings': 4,
#  'South African': 4,
#  'Modern French': 4,
#  'Japanese: Ramen': 4,
#  'Convenience Store with Alcohol': 4,
#  'Eastern European': 4,
#  'Moroccan': 4,
#  'Cambodian': 4,
#  'Gyro': 4,
#  'African: Ethiopian': 4,
#  'Vegetarian / Vegan': 4,
#  'Traditional': 4,
#  'Crepe or Creperie': 4,
#  'Steakhouse': 4,
#  'Dominican': 3,
#  'Flour based food': 3,
#  'Aus Burger': 3,
#  'Teppanyaki': 3,
#  'Canadian': 3,
#  'Burmese': 3,
#  'Yakitori': 3,
#  'Bistro': 3,
#  'Singaporean': 3,
#  'Bacon': 3,
#  'Belgian': 3,
#  'Asian Cuisine': 2,
#  'Syrian': 2,
#  'Momos': 2,
#  'Salad/Sandwiches': 2,
#  'Dim Sum': 2,
#  'Hungarian': 2,
#  'Braised Pork Rice': 2,
#  'Chinese Food': 2,
#  'Specialty': 2,
#  'Tom Yum': 2,
#  'Iranian': 2,
#  'Modern Australian': 2,
#  'Swedish': 2,
#  'Vegan-Friendly': 2,
#  'bookstore': 2,
#  'West Indian': 2,
#  'Arepa': 2,
#  'Pet Supplies': 2,
#  'Eggs': 2,
#  'Congee Boil Rice': 2,
#  'Personal Care': 2,
#  'Juice Bars &amp; Smoothies': 2,
#  'Regalos y flores': 2,
#  'Nigerian': 2,
#  'Farmacia': 2,
#  'Especialidades': 2,
#  'Smoothies': 2,
#  'Ice cream': 2,
#  'Frozen Food': 2,
#  'Ice Cream & Frozen Yogurt': 1,
#  'Braised Dishes': 1,
#  'MarketingCampaign': 1,
#  'Tibetan': 1,
#  'Chinese: Taiwanese': 1,
#  'Scandinavian': 1,
#  'Home &amp; Decor': 1,
#  'Smoke Shop': 1,
#  'Poutine': 1,
#  'Non Halal': 1,
#  'Yucatecan': 1,
#  'Other Asian': 1,
#  'Adult': 1,
#  'Congee': 1,
#  'Sichuan': 1,
#  'Indoor Plants &amp; Gifts': 1,
#  'ButcherShop': 1,
#  'Georgian': 1,
#  'OtherAsian': 1,
#  'Okonomiyaki': 1,
#  'Pet Shop': 1,
#  'Otsumami': 1,
#  'Scottish': 1,
#  'American (New)': 1,
#  'Rotti': 1,
#  'Chinese: Hot Pot': 1,
#  'Armenian': 1,
#  'Neapolitan': 1,
#  'Premium': 1,
#  'Health &amp; Nutrition Supplements': 1,
#  'Sushi Bar': 1,
#  'American (Traditional)': 1,
#  'Sports Bar': 1,
#  'Thali': 1,
#  'Bolivian': 1,
#  'Ameican': 1,
#  'European: Other': 1,
#  'Haitian': 1,
#  'Balkan': 1,
#  'Chilean': 1,
#  'Som Tum': 1,
#  'Snack': 1,
#  'Frozen Yogurt': 1,
#  'Sandwiches/ Salads': 1,
#  'Czech': 1,
#  'Friterie': 1,
#  'Sopas e Caldos': 1,
#  'Local Eats': 1,
#  'FriedRice': 1,
#  'Assorted Stores': 1}
